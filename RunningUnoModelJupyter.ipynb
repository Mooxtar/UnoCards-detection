# %%
# !pip install ultralytics==8.0.196

# %%
import ultralytics

from ultralytics import YOLO

# !yolo task=detect mode=predict model=/Users/mukhtarrabayev/Downloads/content/runs/detect/train8/weights/best.pt conf=0.25 source=/Users/mukhtarrabayev/Downloads/plcards.jpeg
# Out:
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at '/Users/mukhtarrabayev/Library/Application Support/Ultralytics/settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'.
# Ultralytics YOLOv8.0.196 🚀 Python-3.11.5 torch-2.1.2 CPU (Apple M1)
# Model summary (fused): 168 layers, 11131389 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/1 /Users/mukhtarrabayev/Downloads/plcards.jpeg: 640x640 1 numbered-1, 2 numbered-6s, 164.0ms
# Speed: 6.6ms preprocess, 164.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image

image_path = "/Users/mukhtarrabayev/Desktop/runs/detect/predict/plcards.jpeg"

Image(filename=image_path, width=600)
